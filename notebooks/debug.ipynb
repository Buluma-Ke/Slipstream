# %%
import duckdb
con = duckdb.connect('./data/f1.duckdb')

# Do we have results for 2025?
print(con.execute("SELECT count(*) FROM race_results WHERE year = 2025").fetchone())

# Do we have laps for 2025?
print(con.execute("SELECT count(*) FROM laps WHERE year = 2025").fetchone())
con.close()
# Out:
# Running cells with '.venv (3.13.12) (Python 3.13.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Admin/OneDrive/Documentos/Houdini/Slipstream/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
